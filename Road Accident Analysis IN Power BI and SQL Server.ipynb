# %% [markdown]
# # Driving Towards Safety: A Comprehensive Analysis of Road Accidents

# %% [markdown]
# ![](https://img.etimg.com/thumb/msid-101865045,width-1000,height-300,imgsize-20718,,resizemode-75/over-500-people-lost-lives-in-road-accidents-in-bangladesh-road-safety-foundation-report.jpg)

# %% [markdown]
# ### Introduction:
#
# Road accidents stand as a formidable global challenge, exacting a toll in terms of human lives, injuries, and substantial economic losses year after year. Despite concerted efforts by authorities to instill road safety measures, the persistent high incidence of accidents in numerous countries underscores the need for a deeper understanding of the factors contributing to these incidents. In response to this imperative, this project, "Driving Towards Safety," endeavors to embark on an extensive exploration of the multifaceted dimensions surrounding road accidents.
#
# ### Objective
#
# The primary objective of this project is to dissect the intricate web of factors influencing road accidents through a dual approach—leveraging the power of Structured Query Language (SQL) for meticulous data analysis and harnessing the visualization capabilities of PowerBI to convey insights effectively. The project will delve into various dimensions, including the geographic distribution of casualties, monthly trends, vehicle conditions, the state of road infrastructure, and environmental variables. By conducting a thorough investigation into these aspects, This project aspire to unearth patterns, correlations, and insights that can empower authorities in formulating targeted strategies to mitigate the risk of road accidents and, ultimately, save lives.
#
# This project is not merely an exploration of statistics; it is a proactive step towards actionable knowledge. The findings derived from this analysis aim to serve as a foundation upon which authorities can build robust and effective road safety initiatives. Through a combination of rigorous data analysis and intuitive visual representation, "Driving Towards Safety" seeks to contribute to a safer and more secure global road network, fostering environments where accidents are minimized, and lives are safeguarded.
#
# ----
# ### Problem Statement
# Create a Road Accident dashboard for clients for year 2011 so that they can have insight in the below requirements
# - Primary KPI - Total Casualties and Total Accident values for Current Year and Year over year growth
#
# - Primary KPI's - Total Casualties by Accident Severity for Current Year and Year over Year growth
#
# - Secondary KPI's - Total Casualties with respect to vehicle type for Current Year
#
# - Monthly trend showing comparison of casualties for Current Year and Previous Year
#
# - Casualties by Road Type for Current year
#
# - Calalties by Light Condition
#
# - Current Year Casualties by Area/ Location & by Day/Night
#
# - Total Casualties and Total Accidents by Location
#
# ### Data Sourcing
# Not until I came up with the above mentioned questions did I went ahead to get the data online. I then downloaded the [CSV File](https://docs.google.com/spreadsheets/d/1po_7QivCqGceixWVXCoX_ftzf8scG-sl/edit?usp=drive_link), before loading into Power BI for cleaning, analysis and visualization.
#
# It contains 3 sheets/tables:
# 307,973 rows and 14 columns
#
# ----
# ### Data Transformation/Cleaning:
# Data was efficiently cleaned and transformed with the Power Query Editor of Power BI.
# Some of the applied steps included
#
# - Renaming inconsistent data points in Accident_Severity column from Fetal to Fatal.
# - Create calender table
# - Create new features Year, Month, Date from calender table
#
# ### DATA MODELLING
# The 'Data' table is the fact table of the model.
# The remaining dimension tables which I create as time inteligence table; 'Calender' table is connected to the 'Data' table via the common columns: 'Date'.
# ![](modelling.png)
#
#
# **Power BI Concepts applied:**
# - DAX Concepts:
#                 How to connect to raw data,
#                 Data Cleaning in Power Query,
#                 Calculated column,
#                 Custom Measures,
#                 Year(),
#                 Month(),
#                 Day(),
#                 YTD(),
#                 SAMEPERIODLASTYEAR(),
#                 importing Images
#
# - Data Modelling: Star Schema

# %% [markdown]
# ### Data Analysis and Visualization in PowerBI
# ![](Road_Accident_Dashboard.png)
#
#
#
#
# ## <font color = "orange"> Key Insights </font>
#
# 1. **Total Casualties and Trend:**
#    - Total casualties amount to 195.7K, reflecting a notable 11.9% decrease from the previous year.
#
# 2. **Accident Frequency:**
#    - The number of accidents has seen a substantial 11.7% reduction.
#
# 3. **Accident Severity:**
#    - Fatal cases exhibit a significant 33.3% decrease in severity, while slight casualties, the most frequent, experience a 11.9% drop.
#
# 4. **Road Type Impact:**
#    - Over 80% of casualties occur on single carriage roads, emphasizing their high contribution to accidents.
#
# 5. **Time of Day Impact:**
#    - Daytime accounts for 73.62% of total casualties, highlighting higher accident occurrence during daylight hours.
#
# 6. **Urban vs. Rural Impact:**
#    - Casualties in urban areas are higher at 61.95% compared to rural areas.
#
# 7. **Vehicle Type Impact:**
#    - Car accidents surpass other means of road transportation, indicating a higher prevalence.
#
# 8. **Monthly Peaks:**
#    - November witnesses the peak number of casualties, suggesting a concentration of incidents during this month.
#
# 9. **Seasonal Trends:**
#    - Three distinct seasonal casualty trends are identified: February to April, April to August, and August to November.

# %% [markdown]
# ### Road Accident Data  Exploration in SQL

# %% [raw]
# /* ROAD ACCIDENT ANALYSIS IN SQL */
#
# --- Select top 100 rows -------
# SELECT TOP 100  [Index]
#       ,[Accident_Severity]
#       ,[Accident_Date]
#       ,[Latitude]
#       ,[Light_Conditions]
#       ,[District_Area]
#       ,[Longitude]
#       ,[Number_of_Casualties]
#       ,[Number_of_Vehicles]
#       ,[Road_Surface_Conditions]
#       ,[Road_Type]
#       ,[Urban_or_Rural_Area]
#       ,[Weather_Conditions]
#       ,[Vehicle_Type]
#   FROM [RoadAccidentDB].[dbo].[accident data];
# -------------------------------------------------------------------------------------------
#   /* 1. Year of Accident Record*/
#
# SELECT DISTINCT(YEAR([Accident_Date])) as Accident_Year
# FROM  [RoadAccidentDB].[dbo].[accident data]
# ORDER BY 1;
# /* Accident  Year Span between 2019 -2022*/
# -------------------------------------------------------------------------------------------
# /* Current Year Casualties */
# SELECT SUM([Number_of_Casualties]) Current_Year_Casualties
# FROM  [RoadAccidentDB].[dbo].[accident data]
# WHERE YEAR([Accident_Date]) = 2022;
# /* Current_Year_Casualties
#       195737                   */
# ---------------------------------------------------------------------------------------------
# /* Current Year Accident */
#
# SELECT COUNT([Index]) Current_Year_Accident
# FROM  [RoadAccidentDB].[dbo].[accident data]
# WHERE YEAR([Accident_Date]) = 2022;
# /* Current_Year_Accident
#       144419              */
# ----------------------------------------------------------------------------------------------
# /* Accident Severity */
#
# SELECT DISTINCT([Accident_Severity])
# FROM  [RoadAccidentDB].[dbo].[accident data]
#
# --There are Three Accident Severity Type
# --Serious
# --Fatal
# --Slight
#
# /* Current Year Fatal Casualties  */
#
# SELECT SUM([Number_of_Casualties]) Fatal_Casualties
# FROM  [RoadAccidentDB].[dbo].[accident data]
# WHERE [Accident_Severity] = 'Fatal' and YEAR([Accident_Date]) = 2022;
#
# -- Current year Fatal casualties is 2855-------
#
#
# /* Current Year Serious Casualties  */
#
# SELECT SUM([Number_of_Casualties]) Serious_Casualties
# FROM  [RoadAccidentDB].[dbo].[accident data]
# WHERE [Accident_Severity] = 'Serious' and YEAR([Accident_Date]) = 2022;
#
# -- Current year Serious casualties is 27045-----
#
#
# SELECT SUM([Number_of_Casualties]) Slight_Casualties
# FROM  [RoadAccidentDB].[dbo].[accident data]
# WHERE [Accident_Severity] = 'Slight' and YEAR([Accident_Date]) = 2022;
#
# -- Current year Slight casualties is 165837------
#
# ----------------------------------------------------------------------------------------------
#
# /*Current Year Casualties by Vehicle Type  */
#
# SELECT [Vehicle_Type],SUM([Number_of_Casualties]) Veh_casualties
# FROM  [RoadAccidentDB].[dbo].[accident data]
# WHERE YEAR([Accident_Date]) = 2022
# GROUP BY [Vehicle_Type] ORDER BY 2 DESC;
#
# ----Casualties by car top causes of casualties----
#
# ------------------------------------------------------------------------------------------------
#
# /*Current Year Casualties by [Urban_or_Rural_Area]  */
#
# SELECT [Urban_or_Rural_Area],SUM([Number_of_Casualties]) casualties_urban_rural
# FROM  [RoadAccidentDB].[dbo].[accident data]
# WHERE YEAR([Accident_Date]) = 2022
#
# /*
# Urban_or_Rural_Area   	casualties_urban_rural
# Urban	                121251
# Rural	                74486
# 									*/
# ----Casualties by car top causes of casualties----
#
#
# --------------------------------------------------------------------------------------------------
# /*Current Year Casualties by Road_Type  */
#
# SELECT [Road_Type],SUM([Number_of_Casualties]) casualties_by_road
# FROM  [RoadAccidentDB].[dbo].[accident data]
# WHERE YEAR([Accident_Date]) = 2022
# GROUP BY [Road_Type] ORDER BY 2 DESC;
#
# /*
# Road_Type	             casualties_by_road
# Single carriageway	     144653
# Dual carriageway	     31912
# Roundabout	             12683
# One way street	         3499
# Slip road	             2221
# NULL	                 769
# 									*/
# ----Casualties by Single carriageway top causes of Accidents ----
#
# ----------------------------------------------------------------------------------------------------
#
# /*Current Year Casualties by Month  */
#
# SELECT Month([Accident_Date]) Accident_Month,SUM([Number_of_Casualties]) casualties_by_road
# FROM  [RoadAccidentDB].[dbo].[accident data]
# WHERE YEAR([Accident_Date]) = 2022
# GROUP BY Month([Accident_Date])  ORDER BY 2 DESC;
#
# /*
# Accident_Month	casualties_by_road
# 11	                    18439
# 10	                    18287
# 9	                    17500
# 								*/
#
# --- Analysis shows that November top the list of month with casualties followed by october and september--
# ------------------------------------------------------------------------------------------------------------
#
# /*Current Year Casualties by Light_Conditions  */
# SELECT [Light_Conditions],SUM([Number_of_Casualties]) casualties_by_road
# FROM  [RoadAccidentDB].[dbo].[accident data]
# WHERE YEAR([Accident_Date]) = 2022
# GROUP BY [Light_Conditions]  ORDER BY 2 DESC;
#
# ----- Casualties are highest during Daylight------
# ------------------------------------------------------------------------------------------------------------
# /*Current Year Casualties by [District_Area]  */
# SELECT [District_Area],COUNT(*) Number_of_Accidents
# FROM  [RoadAccidentDB].[dbo].[accident data]
# WHERE YEAR([Accident_Date]) = 2022
# GROUP BY [District_Area]  ORDER BY 2 DESC;
#
# /* Top 3 district by number of Accident
# District_Area	Number_of_Accidents
# Birmingham	     2876
# Leeds	        1954
# Bradford	    1439
# 						*/
# ----------------------------------------------------------------------------------------------------------------

# %% [markdown]
# ### Recommendations:
#
# 1. **Targeted Safety Campaigns:**
#    - Given the significant drop in overall casualties and accidents, continue and expand targeted safety campaigns. Focus on educating drivers and promoting responsible behavior on the roads.
#
# 2. **Enhanced Road Infrastructure:**
#    - Address the high proportion of casualties on single carriage roads by investing in road infrastructure improvements. Consider widening roads, implementing safety barriers, and enhancing visibility to reduce accidents.
#
# 3. **Daytime Safety Measures:**
#    - Allocate resources to improve road safety during daytime hours, which account for the majority of accidents. This could involve increased law enforcement, improved signage, and public awareness campaigns tailored to daytime driving risks.
#
# 4. **Urban Safety Initiatives:**
#    - Prioritize urban areas in road safety initiatives, given the higher percentage of casualties. Implement measures such as improved traffic management, pedestrian safety measures, and enhanced infrastructure in urban zones.
#
# 5. **Vehicle Safety Standards:**
#    - Given the prevalence of car accidents, emphasize and enforce vehicle safety standards. Encourage the use of modern safety features, conduct regular vehicle inspections, and promote awareness of safe driving practices.
#
# 6. **Monthly and Seasonal Awareness Programs:**
#    - Launch targeted awareness programs during November, the peak month for casualties, and during the identified seasonal trends. These programs can include increased law enforcement, educational campaigns, and heightened public awareness.
#
# ### Inferences:
#
# 1. **Positive Trend in Road Safety:**
#    - The drop in the number of casualties and accidents indicates a positive trend in road safety, potentially reflecting the effectiveness of existing safety measures and awareness campaigns.
#
# 2. **Impact of Safety Measures:**
#    - The substantial drop in severity for fatal cases and slight casualties suggests that safety measures, whether regulatory or educational, are having a tangible impact on reducing the severity of accidents.
#
# 3. **Need for Rural Safety Focus:**
#    - Despite the overall positive trend, there is a need to focus on rural areas where casualties are still prevalent. Tailored safety initiatives, improved road signage, and increased law enforcement will be particularly beneficial in these regions.
#
# 4. **Daytime Driving Challenges:**
#    - The majority of casualties occurring during daytime hours highlight the specific challenges and risks associated with daytime driving. Addressing factors such as distracted driving and improving road conditions during daylight will further enhance safety.
#
# 5. **Understanding Seasonal Trends:**
#    - Recognizing distinct seasonal casualty trends provides an opportunity for proactive safety measures. Authorities should implement targeted campaigns and resources during specific periods to mitigate the impact of seasonal variations on road safety.
#
# In conclusion, the project's findings offer valuable insights that can guide authorities in refining and developing road safety strategies. The positive trends indicate progress, while identified areas of concern provide clear targets for focused interventions.

# %% [markdown]
# `Job Moses Ubeh inspired by Data Tutorials`
